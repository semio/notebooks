# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

import numpy as np
# Out:
# /usr/local/lib/python3.5/site-packages/matplotlib/__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
plt.rcParams['figure.figsize'] = (8, 8)

# %%
import matplotlib.pyplot as plt

x = [1, 3, 7, 8, 5, 10, 6]

plt.plot(x)
plt.axis([0, 6, 0, 15])
plt.annotate('max', xy=(5,10), xytext=(4, 12),
             arrowprops=dict(facecolor='black'),
             fontsize=20
            )
plt.show()

# %%
matplotlib.rcParams

# %%
matplotlib.get_configdir()

# %%
plt.style.use(["classic", "seaborn-white" ])
# plt.style.reload_library()

# %%
import matplotlib.pyplot as plt

cat = plt.imread('cat.png')
plt.imshow(cat)

# %%
cat[:1]

# %%
from PIL import Image
cat_img = Image.open('cat.png')
cat_img.thumbnail((120, 250))

# %%
from matplotlib.offsetbox import \
OffsetImage, AnnotationBbox

fig, ax = plt.subplots()

imagebox = OffsetImage(cat, zoom=0.3)
ab = AnnotationBbox(imagebox, (0, 0))
ax.add_artist(ab)

plt.xlim(-50, 50)
plt.ylim(-50, 50)

plt.draw()
plt.show()

# %%
resized = img.resize

# %%
cat.shape

# %%
# showing only 2 channels
import matplotlib.pyplot as plt

cat = plt.imread('cat.png')
cat[:,:,0] = 0

plt.imshow(cat)

# %%
import matplotlib.pyplot as plt
import numpy as np

x = [9, 22, 31, 54, 7]
colors = ['yellowgreen', 'gold', 'lightskyblue', 
          'lightcoral', 'lightcyan'
         ]
labels=['apple', 'banana', 'orange', 
          'tomato', 'pear'
        ]
explode=[0, 0.1, 0, 0, 0]

plt.pie(x, labels=labels, explode=explode,
        colors=colors
       )
plt.axis('equal')
plt.show()

# %%
plt.rcParamsDefault

# %%
plt.rcParams['legend.facecolor'] = 'white'
plt.rcParams['legend.fontsize'] = '20'

# %%
cat = plt.imread('cat.png')

# %%
cat.shape
# Out:
# (380, 645, 3)

# %%
from matplotlib.offsetbox import \
OffsetImage, AnnotationBbox

fig, ax = plt.subplots()

cat = plt.imread('cat.png')
imagebox = OffsetImage(cat, zoom=0.3)
ab = AnnotationBbox(imagebox, (0, 0))
ax.add_artist(ab)

plt.xlim(-50, 50)
plt.ylim(-50, 50)
plt.draw()
plt.show()

# %%
rvs = np.random.randn(1000)
plt.hist(rvs, bins=50, histtype='barstacked', alpha=.7)
plt.show()

# %%
x = np.linspace(0, 5)
line, = plt.plot(x, x**2)
plt.setp(line, linestyle='--')
plt.legend([line], ['x**2'])
plt.show()

# %%
plt.set_cmap(plt.cm.Greens)
plt.imshow(np.arange(100).reshape(10, 10))

# %%
plt.set_cmap(plt.cm.BrBG)
plt.imshow(np.arange(100).reshape(10, 10))

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-3, 3)
y = np.sin(x)

plt.xlim(-3, 3)
plt.ylim(-2, 2)

arrowprops1 = {
    "arrowstyle": "->",
    "connectionstyle": "arc3, rad=-0.3",
    "ec": 'black', 
    "lw": 2      
    }

plt.annotate("max: 1.0", xytext=(0, 1.5), xy=(1.5, 1.0),
             arrowprops=arrowprops1, fontsize=20)


arrowprops2 = {
    "arrowstyle": "->",
    "connectionstyle": "arc3, rad=0.3",
    "ec": 'black', 
    "lw": 2      
    }
plt.annotate("min: -1.0", xytext=(-3, -1.5), xy=(-1.5, -1),
             arrowprops=arrowprops2, fontsize=20)


plt.plot(x, y, label='$y=sin(x)$')
plt.legend()
plt.show()

# %%
d1 = np.random.beta(1, 2, 100)

# %%
import numpy as np
import matplotlib.pyplot as plt

d1 = np.random.normal(-3, 2, 1000)
d2 = np.random.normal(0, 3, 1000)
d3 = np.random.normal(3, .6, 1000)

bins = 50
histtype = 'stepfilled'
alpha = .6

plt.hist(d1, bins=bins, histtype=histtype, 
         alpha=alpha, label='$\mu=-3, \sigma=2$')
plt.hist(d2, bins=bins, histtype=histtype, 
         alpha=alpha, label='$\mu=0, \sigma=3$')
plt.hist(d3, bins=bins, histtype=histtype, 
         alpha=alpha, label='$\mu=3, \sigma=0.6$')

plt.legend()
plt.show()

# %%
from zipline.data import load_bars_from_yahoo
from datetime import datetime

# %%
data = load_bars_from_yahoo(stocks=['GOOG'], start='2015-01-01')
# Out:
# GOOG

# %%
data['GOOG'].to_csv('goog.csv')

# %%
data = np.loadtxt('goog.csv', delimiter=',', dtype=object, usecols=(0,0),
                  converters={0: lambda x: datetime.strptime(str(x), "%Y-%m-%d %H:%M:%S+00:00")}, skiprows=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-90959c0e2125> in <module>()
#       1 data = np.loadtxt('goog.csv', delimiter=',', dtype=object, usecols=(0,0),
# ----> 2                   converters={0: lambda x: datetime.strptime(str(x), "%Y-%m-%d %H:%M:%S+00:00")}, skiprows=1)
#
# /usr/local/lib/python3.5/site-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin)
#     926
#     927             # Convert each value according to its column and store
# --> 928             items = [conv(val) for (conv, val) in zip(converters, vals)]
#     929             # Then pack it according to the dtype's nesting
#     930             items = pack_items(items, packing)
#
# /usr/local/lib/python3.5/site-packages/numpy/lib/npyio.py in <listcomp>(.0)
#     926
# ...

# %%
# !head goog.csv
# Out:
# Date,open,high,low,close,volume,price
# 2015-01-02 00:00:00+00:00,529.0123990000001,531.272443,524.102327,524.812404,1447600.0,524.812404
# 2015-01-05 00:00:00+00:00,523.2623769999999,524.3323889999999,513.062315,513.872306,2059800.0,513.872306
# 2015-01-06 00:00:00+00:00,515.002358,516.177334,501.05226600000003,501.962262,2899900.0,501.962262
# 2015-01-07 00:00:00+00:00,507.00229900000005,507.24628499999994,499.652247,501.102268,2065100.0,501.102268
# 2015-01-08 00:00:00+00:00,497.992238,503.4823,491.002212,502.682255,3353600.0,502.682255
# 2015-01-09 00:00:00+00:00,504.7623,504.922285,494.79223899999994,496.172274,2069400.0,496.172274
# 2015-01-12 00:00:00+00:00,494.94224699999995,495.97826100000003,487.562205,492.552209,2322400.0,492.552209
# 2015-01-13 00:00:00+00:00,498.84225599999996,502.98230199999995,492.392254,496.18225099999995,2370500.0,496.18225099999995
# 2015-01-14 00:00:00+00:00,494.652237,503.23228600000004,493.002234,500.87226699999997,2235700.0,500.87226699999997

# %%
data = np.loadcsv

# %%
data = np.load

# %%
def logit(x):
    return 1 / (1 + np.exp(-x))

# %%
x = np.linspace(-6, 6)

plt.plot(x, logit(x))

# %%
x = np.linspace(-6, 6)
y = np.linspace(-6, 6)
x_g, y_g = np.meshgrid(x, y)

# %%
z = logit(x_g+y_g)

# %%
plt.style.use(['classic', 'seaborn-white', 'seaborn-talk'])

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D


x = np.linspace(-4, 4)
y = np.linspace(-4, 4)
x_g, y_g = np.meshgrid(x, y)

R = np.sqrt(x_g**2 + y_g**2)
Z = np.sin(R)


fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')

ax.plot_surface(x_g, y_g, Z, cmap=plt.cm.coolwarm, 
                rstride=1, cstride=1, alpha=.7)
# ax.contourf(x_g, y_g, z, zdir='z', cmap=plt.cm.hot)
ax.view_init(elev=30., azim=-60)
plt.tight_layout()

# %%
from mpl_toolkits.mplot3d import Axes3D

x = np.linspace(-4, 4)
y = np.linspace(-4, 4)
x_g, y_g = np.meshgrid(x, y)
R = np.sqrt(x_g**2 + y_g**2)
Z = np.sin(R)

plt.contourf(x_g, y_g, Z, cmap=plt.cm.coolwarm)
# also try plt.pcolormesh

plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt
# plt.figsize(11, 9)

import scipy.stats as stats

dist = stats.beta
n_trials = [0, 1, 2, 3, 4, 5, 8, 15, 50, 500]
data = stats.bernoulli.rvs(0.5, size=n_trials[-1])
x = np.linspace(0, 1, 100)

# For the already prepared, I'm using Binomial's conj. prior.
for k, N in enumerate(n_trials):
    sx = plt.subplot(len(n_trials) / 2, 2, k + 1)
    plt.xlabel("$p$, probability of heads") \
        if k in [0, len(n_trials) - 1] else None
    plt.setp(sx.get_yticklabels(), visible=False)
    heads = data[:N].sum()
    y = dist.pdf(x, 1 + heads, 1 + N - heads)
    plt.plot(x, y, label="observe %d tosses,\n %d heads" % (N, heads))
    plt.fill_between(x, 0, y, color="#348ABD", alpha=0.4)
    plt.vlines(0.5, 0, 4, color="k", linestyles="--", lw=1)

    leg = plt.legend()
    leg.get_frame().set_alpha(0.4)
    plt.autoscale(tight=True)


plt.suptitle("Bayesian updating of posterior probabilities",
             y=1.02,
             fontsize=14)

plt.tight_layout()

# %%
X = np.linspace(-np.pi, np.pi, endpoint=True)
S = np.sin(X)

plt.plot(X, S, color="red", linewidth=2.5, linestyle="-",  label="sin(x)")

ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position('center')
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position('center')
plt.xlim(-4, 4)
plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi],
          [r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])
plt.ylim(-1.2, 1.2)
plt.yticks([-1, +1],
          [r'$-1$', r'$+1$'])
t = np.pi / 2
plt.plot([t, t], [0, np.sin(t)],
        color='red', linewidth=1.5, linestyle="--")
plt.scatter([t, ], [np.sin(t), ], 50, color='red')
plt.annotate(r'$sin(\frac{\pi}{2})=1$',
            xy=(t, np.sin(t)), xycoords='data',
            xytext=(+10, +30), textcoords='offset points', fontsize=16,
            arrowprops=dict(arrowstyle="->", connectionstyle="arc3,rad=.2"))
plt.plot([-t, -t], [0, np.sin(-t)],
        color='red', linewidth=1.5, linestyle="--")
plt.scatter([-t, ], [np.sin(-t), ], 50, color='red')
plt.annotate(r'$cos(-\frac{\pi}{2})=-1$', xy=(-t, np.sin(-t)),
            xycoords='data', xytext=(-90, -40), textcoords='offset points',
            fontsize=16,
            arrowprops=dict(arrowstyle="->", connectionstyle="arc3,rad=.2"))
plt.legend(loc='upper left', frameon=True, fancybox=True)
plt.title('plot for sin(x)', fontsize=17, y=1.03)
plt.show()

# %%
from matplotlib.finance import fetch_historical_yahoo, parse_yahoo_historical_ohlc, quotes_historical_yahoo_ochl
from datetime import datetime

data = fetch_historical_yahoo('GOOG', (2015, 1, 1), datetime.today())

# %%
d = quotes_historical_yahoo_ochl('GOOG', (2015, 2, 1), datetime.today(), asobject=True)

# %%
from matplotlib import gridspec
# from matplotlib.dates import date2num
ret = d.close[1:] - d.close[:-1]
ret = np.r_[0, ret]
colors = ['g' if x>0 else 'r' for x in ret ]
gs = gridspec.GridSpec(2, 1, height_ratios=[3, 1]) 
ax0 = plt.subplot(gs[0])
ax0.plot(d.date, d.close, alpha=.8, color='blue')
# ax0.scatter(d.date, d.close, 20, color=colors)
ax0.fill_between(d.date, d.close, 500, alpha=.4, color='blue', interpolate=True)
ax0.grid(alpha=.7, linestyle='dashed')
plt.setp(ax0.get_xticklabels(), visible=False)
ax1 = plt.subplot(gs[1], sharex=ax0)
ax1.bar(d.date, d.volume, color=colors, alpha=.8)
ax1.grid(alpha=.7, linestyle='dashed')
plt.xticks(rotation=60)
plt.tight_layout()
plt.suptitle('GOOG Daily', y=1.02)

# %%
ret = d.close[1:] - d.close[:-1]

# %%
ret = np.r_[0, ret]

# %%
colors = ['g' if x>0 else 'r' for x in ret ]

# %%
sdf = d.date

# %%
sdf.astype(float)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-252-0a85d4fa5570> in <module>()
# ----> 1 sdf.astype(float)
#
# TypeError: float() argument must be a string or a number, not 'datetime.date'
